# %%
import os
from google.colab import drive
from google.colab import userdata

drive.mount("/content/drive")

HF_TOKEN = userdata.get("HF_TOKEN")
os.environ["HF_TOKEN"] = HF_TOKEN

print("\nHugging Face Token successfully set.")

OPENAI_API_KEY = userdata.get("OPENAI_API")
os.environ["OPENAI_API"] = OPENAI_API_KEY

print("\nOpenAI API successfully set.\n")

# %cd /content/drive/MyDrive/ES-CSA/data/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Hugging Face Token successfully set.
#
# OpenAI API successfully set.
#
# /content/drive/MyDrive/ES-CSA/data

# %%
import json
import pandas as pd

# %%
# Processing Consumer_Data_Summary for Embeddings

consumer_data_path = "processed/consumer_data_summary.json"

with open(consumer_data_path, "r") as f:
    consumer_data = json.load(f)

def format_user_profile(user):
    """Generates structured text representation of user profile."""
    return f"{user['User Profile']['Name']} from {user['User Profile']['City']} is on a {user['User Profile']['Plan Type']} plan."

def format_cdrs(cdrs):
    """Generates structured text representation of call detail records."""
    return [
        f"On {record['Date']}, user used {record['Resource Used']} resources and was charged {record['Charge (PKR)']} PKR."
        for record in cdrs
    ]

def format_purchases(purchases):
    """Generates structured text representation of purchase history."""
    return [
        (f"On {purchase['Date']}, user spent {purchase['Amount Spent (PKR)']} PKR purchasing "
         f"{purchase['Data Browsing (MB)']} MB of browsing data, {purchase['Data Social (MB)']} MB for social media, "
         f"{purchase['SMS']} SMS, {purchase['Voice On-Net (min)']} on-net voice minutes, and "
         f"{purchase['Voice Off-Net (min)']} off-net voice minutes.")
        for purchase in purchases
    ]

def format_tickets(tickets):
    """Generates structured text representation of customer support tickets."""
    return [
        (f"Ticket {ticket['Ticket ID']} was logged on {ticket['Logged Time']} under {ticket['Category']} category. "
         f"Description: {ticket['Description']} The ticket was resolved on {ticket['Resolved Time']} "
         f"with the following resolution: {ticket['Resolution']}.")
        for ticket in tickets
    ]

user_representations = []
for user in consumer_data:
    structured_entry = {
        "User Profile": format_user_profile(user),
        "Call Detail Records": format_cdrs(user["CDRS"]),
        "Purchases": format_purchases(user["Purchases"]),
        "Tickets": format_tickets(user["Tickets"])
    }
    user_representations.append(structured_entry)

for i, text in enumerate(user_representations[:1]):
    print(f"User {i+1} Details:\n{text}\n{'-'*80}")
# Out:
# User 1 Details:
# {'User Profile': 'User 1 from Lahore is on a Prepaid plan.', 'Call Detail Records': ['On 2024-10-26T22:44:08, user used 211 voice resources and was charged 10 PKR.', 'On 2023-05-23T07:54:33, user used 34 data resources and was charged 0 PKR.', 'On 2023-10-12T09:06:27, user used 36 voice resources and was charged 0 PKR.', 'On 2024-01-21T13:20:44, user used 25 data resources and was charged 0 PKR.', 'On 2023-07-31T16:27:19, user used 18 data resources and was charged 11 PKR.', 'On 2023-12-24T01:07:33, user used 229 voice resources and was charged 5 PKR.', 'On 2024-11-09T17:08:02, user used 12 sms resources and was charged 0 PKR.'], 'Purchases': ['On 2024-11-06T15:50:55, user spent 912 PKR purchasing 4572 MB of browsing data, 836 MB for social media, 564 SMS, 416 on-net voice minutes, and 168 off-net voice minutes.', 'On 2024-01-13T08:17:43, user spent 639 PKR purchasing 4545 MB of browsing data, 2373 MB for social media, 488 SMS, 387 on-net voice minutes, and 175 off-net voice minutes.', 'On 2024-12-19T06:47:08, user spent 501 PKR purchasing 3128 MB of browsing data, 1596 MB for social media, 546 SMS, 72 on-net voice minutes, and 202 off-net voice minutes.', 'On 2024-01-21T00:03:17, user spent 645 PKR purchasing 9027 MB of browsing data, 1123 MB for social media, 652 SMS, 469 on-net voice minutes, and 29 off-net voice minutes.', 'On 2024-02-25T21:50:38, user spent 467 PKR purchasing 3630 MB of browsing data, 1830 MB for social media, 849 SMS, 269 on-net voice minutes, and 208 off-net voice minutes.', 'On 2023-09-01T13:40:22, user spent 802 PKR purchasing 3493 MB of browsing data, 1732 MB for social media, 358 SMS, 321 on-net voice minutes, and 160 off-net voice minutes.', 'On 2024-06-27T01:48:26, user spent 192 PKR purchasing 5057 MB of browsing data, 2482 MB for social media, 340 SMS, 127 on-net voice minutes, and 32 off-net voice minutes.', 'On 2024-07-24T13:07:11, user spent 990 PKR purchasing 5950 MB of browsing data, 963 MB for social media, 457 SMS, 360 on-net voice minutes, and 183 off-net voice minutes.'], 'Tickets': ['Ticket T44316 was logged on 2024-09-15T03:19:13 under Billing category. Description: Issue reported under Billing category. The ticket was resolved on 2024-09-16T22:19:13 with the following resolution: Resolved with detailed explanation for Billing category..', 'Ticket T74113 was logged on 2024-09-30T11:34:24 under Network Issue category. Description: Issue reported under Network Issue category. The ticket was resolved on 2024-09-30T20:34:24 with the following resolution: Resolved with detailed explanation for Network Issue category..', 'Ticket T38012 was logged on 2024-08-20T23:08:37 under Complaint category. Description: Issue reported under Complaint category. The ticket was resolved on 2024-08-22T13:08:37 with the following resolution: Resolved with detailed explanation for Complaint category..', 'Ticket T41319 was logged on 2024-01-14T17:10:45 under Complaint category. Description: Issue reported under Complaint category. The ticket was resolved on 2024-01-16T16:10:45 with the following resolution: Resolved with detailed explanation for Complaint category..', 'Ticket T70600 was logged on 2023-06-13T19:21:32 under Billing category. Description: Issue reported under Billing category. The ticket was resolved on 2023-06-16T19:21:32 with the following resolution: Resolved with detailed explanation for Billing category..', 'Ticket T50539 was logged on 2023-07-24T10:09:43 under General Inquiry category. Description: Issue reported under General Inquiry category. The ticket was resolved on 2023-07-24T23:09:43 with the following resolution: Resolved with detailed explanation for General Inquiry category..', 'Ticket T82890 was logged on 2024-11-07T15:19:54 under Technical Support category. Description: Issue reported under Technical Support category. The ticket was resolved on 2024-11-08T02:19:54 with the following resolution: Resolved with detailed explanation for Technical Support category..', 'Ticket T51057  ...
# --------------------------------------------------------------------------------

# %%
# Saving Formatted Consumer Data Summary

consumer_data_formatted_path = "processed/consumer_data_formatted.json"

with open(consumer_data_formatted_path, "w") as f:
    json.dump(user_representations, f, indent=4)

print(f"Saved formatted consumer data summary.")
# Out:
# Saved formatted consumer data summary.

# %%
# Processing Consumer_Insights_Summary for Embeddings

consumer_insights_path = "processed/consumer_insights_summary.json"

with open(consumer_insights_path, "r", encoding="utf-8") as file:
    consumer_insights = json.load(file)

def generate_text_summary(consumer):
    msisdn = consumer["MSISDN"]
    insights = consumer["User Insights"]

    text_summary = (
        f"User {msisdn} has consumed {insights['Total Data Consumed']} MB of data, "
        f"sent {insights['Total SMS Consumed']} SMS, and used {insights['Total Voice Consumed']} minutes of voice calls. "
        f"They have spent {insights['Total Amount Spent on Data']} PKR on data, "
        f"{insights['Total Amount Spent on SMS']} PKR on SMS, and {insights['Total Amount Spent on Voice']} PKR on voice services. "
        f"Their total charged amount is {insights['Total Amount Charged']} PKR "
        f"across {insights['Transaction Count']} transactions. "
        f"They have made {insights['Total Purchase Transactions']} purchases, with a total purchase value of {insights['Total Amount Purchases']} PKR. "
        f"They have raised {insights['Total Tickets']} support tickets."
    )

    return {
        "MSISDN": msisdn,
        "User Insights": text_summary
    }

formatted_insights = [generate_text_summary(user) for user in consumer_insights]

print(json.dumps(formatted_insights, indent=4))
# Out:
# [
#     {
#         "MSISDN": "9230101039883",
#         "User Insights": "User 9230101039883 has consumed 167 MB of data, sent 79 SMS, and used 262 minutes of voice calls. They have spent 24 PKR on data, 24 PKR on SMS, and 33 PKR on voice services. Their total charged amount is 81 PKR across 10 transactions. They have made 16 purchases, with a total purchase value of 9287 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230102123429",
#         "User Insights": "User 9230102123429 has consumed 188 MB of data, sent 157 SMS, and used 0 minutes of voice calls. They have spent 19 PKR on data, 19 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 38 PKR across 10 transactions. They have made 6 purchases, with a total purchase value of 4195 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230104488435",
#         "User Insights": "User 9230104488435 has consumed 311 MB of data, sent 112 SMS, and used 270 minutes of voice calls. They have spent 20 PKR on data, 11 PKR on SMS, and 8 PKR on voice services. Their total charged amount is 39 PKR across 11 transactions. They have made 17 purchases, with a total purchase value of 9423 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230108284824",
#         "User Insights": "User 9230108284824 has consumed 0 MB of data, sent 79 SMS, and used 211 minutes of voice calls. They have spent 0 PKR on data, 65 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 65 PKR across 9 transactions. They have made 14 purchases, with a total purchase value of 7354 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230108807547",
#         "User Insights": "User 9230108807547 has consumed 153 MB of data, sent 154 SMS, and used 164 minutes of voice calls. They have spent 6 PKR on data, 47 PKR on SMS, and 16 PKR on voice services. Their total charged amount is 69 PKR across 13 transactions. They have made 9 purchases, with a total purchase value of 3167 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230110752086",
#         "User Insights": "User 9230110752086 has consumed 191 MB of data, sent 0 SMS, and used 1304 minutes of voice calls. They have spent 10 PKR on data, 0 PKR on SMS, and 46 PKR on voice services. Their total charged amount is 56 PKR across 9 transactions. They have made 8 purchases, with a total purchase value of 3145 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230113042916",
#         "User Insights": "User 9230113042916 has consumed 37 MB of data, sent 162 SMS, and used 230 minutes of voice calls. They have spent 6 PKR on data, 28 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 34 PKR across 7 transactions. They have made 6 purchases, with a total purchase value of 3549 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230114635206",
#         "User Insights": "User 9230114635206 has consumed 251 MB of data, sent 9 SMS, and used 0 minutes of voice calls. They have spent 48 PKR on data, 2 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 50 PKR across 7 transactions. They have made 4 purchases, with a total purchase value of 2424 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230116725380",
#         "User Insights": "User 9230116725380 has consumed 139 MB of data, sent 24 SMS, and used 437 minutes of voice calls. They have spent 21 PKR on data, 0 PKR on SMS, and 13 PKR on voice services. Their total charged amount is 34 PKR across 10 transactions. They have made 7 purchases, with a total purchase value of 4702 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230128026064",
#         "User Insights": "User 9230128026064 has consumed 160 MB of data, sent 96 SMS, and used 863 minutes of voice calls. They have spent 13 PKR on data, 13 PKR on SMS, and 54 PKR on voice services. Their total charged amount is 80 PKR across 12 transactions. They have made 9 purchases, with a total purchase value of 4798 PKR. They have raised 5 support tickets."
#     },
#     {
#         "MSISDN": "9230128262006",
#         "User Insights": "User 9230128262006 has consumed 0 MB of data, sent 56 SMS, and used 294 minutes of voice calls. They have spent 0 PKR on data, 19 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 33 PKR across 5 transactions. They have made 9 purchases, with a total purchase value of 3950 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230130432269",
#         "User Insights": "User 9230130432269 has consumed 192 MB of data, sent 76 SMS, and used 391 minutes of voice calls. They have spent 30 PKR on data, 0 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 41 PKR across 11 transactions. They have made 12 purchases, with a total purchase value of 5020 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230130590594",
#         "User Insights": "User 9230130590594 has consumed 53 MB of data, sent 64 SMS, and used 540 minutes of voice calls. They have spent 27 PKR on data, 28 PKR on SMS, and 2 PKR on voice services. Their total charged amount is 57 PKR across 6 transactions. They have made 5 purchases, with a total purchase value of 2726 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230130862663",
#         "User Insights": "User 9230130862663 has consumed 197 MB of data, sent 0 SMS, and used 199 minutes of voice calls. They have spent 14 PKR on data, 0 PKR on SMS, and 16 PKR on voice services. Their total charged amount is 30 PKR across 5 transactions. They have made 9 purchases, with a total purchase value of 4839 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230131212541",
#         "User Insights": "User 9230131212541 has consumed 95 MB of data, sent 64 SMS, and used 0 minutes of voice calls. They have spent 26 PKR on data, 0 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 26 PKR across 7 transactions. They have made 8 purchases, with a total purchase value of 4797 PKR. They have raised 16 support tickets."
#     },
#     {
#         "MSISDN": "9230131213667",
#         "User Insights": "User 9230131213667 has consumed 216 MB of data, sent 103 SMS, and used 96 minutes of voice calls. They have spent 21 PKR on data, 18 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 39 PKR across 9 transactions. They have made 15 purchases, with a total purchase value of 8276 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230131679184",
#         "User Insights": "User 9230131679184 has consumed 20 MB of data, sent 58 SMS, and used 538 minutes of voice calls. They have spent 0 PKR on data, 3 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 3 PKR across 8 transactions. They have made 18 purchases, with a total purchase value of 8950 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230132527460",
#         "User Insights": "User 9230132527460 has consumed 241 MB of data, sent 83 SMS, and used 144 minutes of voice calls. They have spent 5 PKR on data, 33 PKR on SMS, and 1 PKR on voice services. Their total charged amount is 39 PKR across 8 transactions. They have made 10 purchases, with a total purchase value of 3874 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230134569915",
#         "User Insights": "User 9230134569915 has consumed 0 MB of data, sent 134 SMS, and used 1015 minutes of voice calls. They have spent 0 PKR on data, 8 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 28 PKR across 11 transactions. They have made 10 purchases, with a total purchase value of 3651 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230135697838",
#         "User Insights": "User 9230135697838 has consumed 449 MB of data, sent 134 SMS, and used 159 minutes of voice calls. They have spent 34 PKR on data, 37 PKR on SMS, and 12 PKR on voice services. Their total charged amount is 83 PKR across 14 transactions. They have made 12 purchases, with a total purchase value of 5261 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230135736693",
#         "User Insights": "User 9230135736693 has consumed 191 MB of data, sent 121 SMS, and used 578 minutes of voice calls. They have spent 21 PKR on data, 18 PKR on SMS, and 15 PKR on voice services. Their total charged amount is 54 PKR across 11 transactions. They have made 10 purchases, with a total purchase value of 4862 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230136074684",
#         "User Insights": "User 9230136074684 has consumed 95 MB of data, sent 69 SMS, and used 555 minutes of voice calls. They have spent 17 PKR on data, 17 PKR on SMS, and 33 PKR on voice services. Their total charged amount is 67 PKR across 7 transactions. They have made 12 purchases, with a total purchase value of 6590 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230136370951",
#         "User Insights": "User 9230136370951 has consumed 234 MB of data, sent 148 SMS, and used 693 minutes of voice calls. They have spent 10 PKR on data, 58 PKR on SMS, and 34 PKR on voice services. Their total charged amount is 102 PKR across 16 transactions. They have made 12 purchases, with a total purchase value of 7160 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230140927318",
#         "User Insights": "User 9230140927318 has consumed 93 MB of data, sent 111 SMS, and used 885 minutes of voice calls. They have spent 20 PKR on data, 6 PKR on SMS, and 1 PKR on voice services. Their total charged amount is 27 PKR across 9 transactions. They have made 11 purchases, with a total purchase value of 5775 PKR. They have raised 3 support tickets."
#     },
#     {
#         "MSISDN": "9230141002657",
#         "User Insights": "User 9230141002657 has consumed 192 MB of data, sent 112 SMS, and used 169 minutes of voice calls. They have spent 13 PKR on data, 16 PKR on SMS, and 29 PKR on voice services. Their total charged amount is 58 PKR across 12 transactions. They have made 9 purchases, with a total purchase value of 4141 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230141894241",
#         "User Insights": "User 9230141894241 has consumed 171 MB of data, sent 135 SMS, and used 460 minutes of voice calls. They have spent 52 PKR on data, 4 PKR on SMS, and 1 PKR on voice services. Their total charged amount is 57 PKR across 14 transactions. They have made 4 purchases, with a total purchase value of 2393 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230150956349",
#         "User Insights": "User 9230150956349 has consumed 210 MB of data, sent 22 SMS, and used 398 minutes of voice calls. They have spent 49 PKR on data, 31 PKR on SMS, and 5 PKR on voice services. Their total charged amount is 85 PKR across 10 transactions. They have made 12 purchases, with a total purchase value of 6392 PKR. They have raised 16 support tickets."
#     },
#     {
#         "MSISDN": "9230156332171",
#         "User Insights": "User 9230156332171 has consumed 95 MB of data, sent 138 SMS, and used 0 minutes of voice calls. They have spent 12 PKR on data, 52 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 64 PKR across 7 transactions. They have made 10 purchases, with a total purchase value of 4268 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230161844343",
#         "User Insights": "User 9230161844343 has consumed 231 MB of data, sent 78 SMS, and used 589 minutes of voice calls. They have spent 10 PKR on data, 1 PKR on SMS, and 37 PKR on voice services. Their total charged amount is 48 PKR across 13 transactions. They have made 11 purchases, with a total purchase value of 6554 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230162731400",
#         "User Insights": "User 9230162731400 has consumed 75 MB of data, sent 103 SMS, and used 345 minutes of voice calls. They have spent 1 PKR on data, 49 PKR on SMS, and 28 PKR on voice services. Their total charged amount is 78 PKR across 12 transactions. They have made 13 purchases, with a total purchase value of 6249 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230164210176",
#         "User Insights": "User 9230164210176 has consumed 6 MB of data, sent 107 SMS, and used 58 minutes of voice calls. They have spent 9 PKR on data, 14 PKR on SMS, and 22 PKR on voice services. Their total charged amount is 45 PKR across 9 transactions. They have made 9 purchases, with a total purchase value of 5987 PKR. They have raised 3 support tickets."
#     },
#     {
#         "MSISDN": "9230164904391",
#         "User Insights": "User 9230164904391 has consumed 196 MB of data, sent 87 SMS, and used 123 minutes of voice calls. They have spent 30 PKR on data, 14 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 44 PKR across 8 transactions. They have made 16 purchases, with a total purchase value of 6526 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230166511912",
#         "User Insights": "User 9230166511912 has consumed 91 MB of data, sent 14 SMS, and used 489 minutes of voice calls. They have spent 1 PKR on data, 19 PKR on SMS, and 12 PKR on voice services. Their total charged amount is 32 PKR across 6 transactions. They have made 7 purchases, with a total purchase value of 3847 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230169412325",
#         "User Insights": "User 9230169412325 has consumed 112 MB of data, sent 0 SMS, and used 684 minutes of voice calls. They have spent 13 PKR on data, 0 PKR on SMS, and 28 PKR on voice services. Their total charged amount is 41 PKR across 7 transactions. They have made 7 purchases, with a total purchase value of 4097 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230172475544",
#         "User Insights": "User 9230172475544 has consumed 284 MB of data, sent 180 SMS, and used 640 minutes of voice calls. They have spent 31 PKR on data, 44 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 79 PKR across 15 transactions. They have made 13 purchases, with a total purchase value of 5862 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230174337699",
#         "User Insights": "User 9230174337699 has consumed 171 MB of data, sent 75 SMS, and used 777 minutes of voice calls. They have spent 28 PKR on data, 23 PKR on SMS, and 13 PKR on voice services. Their total charged amount is 64 PKR across 10 transactions. They have made 10 purchases, with a total purchase value of 6146 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230174392318",
#         "User Insights": "User 9230174392318 has consumed 174 MB of data, sent 58 SMS, and used 166 minutes of voice calls. They have spent 14 PKR on data, 3 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 17 PKR across 7 transactions. They have made 13 purchases, with a total purchase value of 5011 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230175168797",
#         "User Insights": "User 9230175168797 has consumed 240 MB of data, sent 61 SMS, and used 311 minutes of voice calls. They have spent 46 PKR on data, 0 PKR on SMS, and 8 PKR on voice services. Their total charged amount is 54 PKR across 10 transactions. They have made 13 purchases, with a total purchase value of 7747 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230175549082",
#         "User Insights": "User 9230175549082 has consumed 219 MB of data, sent 120 SMS, and used 1122 minutes of voice calls. They have spent 22 PKR on data, 15 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 48 PKR across 12 transactions. They have made 7 purchases, with a total purchase value of 4601 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230177089747",
#         "User Insights": "User 9230177089747 has consumed 294 MB of data, sent 69 SMS, and used 521 minutes of voice calls. They have spent 47 PKR on data, 15 PKR on SMS, and 29 PKR on voice services. Their total charged amount is 91 PKR across 11 transactions. They have made 6 purchases, with a total purchase value of 3780 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230181101498",
#         "User Insights": "User 9230181101498 has consumed 76 MB of data, sent 67 SMS, and used 0 minutes of voice calls. They have spent 18 PKR on data, 8 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 26 PKR across 5 transactions. They have made 6 purchases, with a total purchase value of 2403 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230181232816",
#         "User Insights": "User 9230181232816 has consumed 279 MB of data, sent 108 SMS, and used 79 minutes of voice calls. They have spent 0 PKR on data, 21 PKR on SMS, and 15 PKR on voice services. Their total charged amount is 36 PKR across 9 transactions. They have made 7 purchases, with a total purchase value of 3244 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230182771385",
#         "User Insights": "User 9230182771385 has consumed 165 MB of data, sent 85 SMS, and used 0 minutes of voice calls. They have spent 11 PKR on data, 13 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 24 PKR across 7 transactions. They have made 13 purchases, with a total purchase value of 5318 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230184750806",
#         "User Insights": "User 9230184750806 has consumed 383 MB of data, sent 69 SMS, and used 348 minutes of voice calls. They have spent 44 PKR on data, 14 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 69 PKR across 11 transactions. They have made 13 purchases, with a total purchase value of 7046 PKR. They have raised 4 support tickets."
#     },
#     {
#         "MSISDN": "9230185115570",
#         "User Insights": "User 9230185115570 has consumed 246 MB of data, sent 43 SMS, and used 414 minutes of voice calls. They have spent 33 PKR on data, 34 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 87 PKR across 10 transactions. They have made 8 purchases, with a total purchase value of 4229 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230189367566",
#         "User Insights": "User 9230189367566 has consumed 253 MB of data, sent 0 SMS, and used 490 minutes of voice calls. They have spent 29 PKR on data, 0 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 49 PKR across 11 transactions. They have made 8 purchases, with a total purchase value of 4938 PKR. They have raised 5 support tickets."
#     },
#     {
#         "MSISDN": "9230191688658",
#         "User Insights": "User 9230191688658 has consumed 200 MB of data, sent 101 SMS, and used 716 minutes of voice calls. They have spent 0 PKR on data, 25 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 29 PKR across 11 transactions. They have made 7 purchases, with a total purchase value of 4978 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230195976999",
#         "User Insights": "User 9230195976999 has consumed 259 MB of data, sent 86 SMS, and used 1761 minutes of voice calls. They have spent 21 PKR on data, 11 PKR on SMS, and 51 PKR on voice services. Their total charged amount is 83 PKR across 19 transactions. They have made 10 purchases, with a total purchase value of 5383 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230198819986",
#         "User Insights": "User 9230198819986 has consumed 153 MB of data, sent 190 SMS, and used 383 minutes of voice calls. They have spent 17 PKR on data, 13 PKR on SMS, and 19 PKR on voice services. Their total charged amount is 49 PKR across 10 transactions. They have made 8 purchases, with a total purchase value of 4778 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230199794288",
#         "User Insights": "User 9230199794288 has consumed 283 MB of data, sent 90 SMS, and used 223 minutes of voice calls. They have spent 27 PKR on data, 5 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 32 PKR across 11 transactions. They have made 17 purchases, with a total purchase value of 8652 PKR. They have raised 17 support tickets."
#     },
#     {
#         "MSISDN": "9230200289727",
#         "User Insights": "User 9230200289727 has consumed 287 MB of data, sent 55 SMS, and used 126 minutes of voice calls. They have spent 27 PKR on data, 4 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 31 PKR across 11 transactions. They have made 8 purchases, with a total purchase value of 5738 PKR. They have raised 19 support tickets."
#     },
#     {
#         "MSISDN": "9230202281036",
#         "User Insights": "User 9230202281036 has consumed 0 MB of data, sent 2 SMS, and used 135 minutes of voice calls. They have spent 0 PKR on data, 0 PKR on SMS, and 2 PKR on voice services. Their total charged amount is 2 PKR across 3 transactions. They have made 12 purchases, with a total purchase value of 5882 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230203803040",
#         "User Insights": "User 9230203803040 has consumed 441 MB of data, sent 11 SMS, and used 462 minutes of voice calls. They have spent 28 PKR on data, 0 PKR on SMS, and 26 PKR on voice services. Their total charged amount is 54 PKR across 11 transactions. They have made 9 purchases, with a total purchase value of 4428 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230203822216",
#         "User Insights": "User 9230203822216 has consumed 174 MB of data, sent 188 SMS, and used 455 minutes of voice calls. They have spent 0 PKR on data, 32 PKR on SMS, and 22 PKR on voice services. Their total charged amount is 54 PKR across 13 transactions. They have made 10 purchases, with a total purchase value of 5950 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230206172868",
#         "User Insights": "User 9230206172868 has consumed 273 MB of data, sent 89 SMS, and used 385 minutes of voice calls. They have spent 21 PKR on data, 20 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 45 PKR across 12 transactions. They have made 7 purchases, with a total purchase value of 4241 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230206993428",
#         "User Insights": "User 9230206993428 has consumed 54 MB of data, sent 139 SMS, and used 296 minutes of voice calls. They have spent 16 PKR on data, 34 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 50 PKR across 8 transactions. They have made 11 purchases, with a total purchase value of 5230 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230208786773",
#         "User Insights": "User 9230208786773 has consumed 212 MB of data, sent 227 SMS, and used 496 minutes of voice calls. They have spent 17 PKR on data, 40 PKR on SMS, and 13 PKR on voice services. Their total charged amount is 70 PKR across 17 transactions. They have made 9 purchases, with a total purchase value of 3628 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230210475028",
#         "User Insights": "User 9230210475028 has consumed 336 MB of data, sent 109 SMS, and used 1128 minutes of voice calls. They have spent 50 PKR on data, 46 PKR on SMS, and 33 PKR on voice services. Their total charged amount is 129 PKR across 17 transactions. They have made 13 purchases, with a total purchase value of 6529 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230213698765",
#         "User Insights": "User 9230213698765 has consumed 122 MB of data, sent 205 SMS, and used 784 minutes of voice calls. They have spent 13 PKR on data, 16 PKR on SMS, and 21 PKR on voice services. Their total charged amount is 50 PKR across 12 transactions. They have made 5 purchases, with a total purchase value of 2630 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230214230900",
#         "User Insights": "User 9230214230900 has consumed 497 MB of data, sent 109 SMS, and used 693 minutes of voice calls. They have spent 56 PKR on data, 20 PKR on SMS, and 21 PKR on voice services. Their total charged amount is 97 PKR across 15 transactions. They have made 11 purchases, with a total purchase value of 5661 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230216678436",
#         "User Insights": "User 9230216678436 has consumed 182 MB of data, sent 35 SMS, and used 294 minutes of voice calls. They have spent 27 PKR on data, 0 PKR on SMS, and 17 PKR on voice services. Their total charged amount is 44 PKR across 6 transactions. They have made 7 purchases, with a total purchase value of 4389 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230218302795",
#         "User Insights": "User 9230218302795 has consumed 100 MB of data, sent 75 SMS, and used 530 minutes of voice calls. They have spent 0 PKR on data, 15 PKR on SMS, and 3 PKR on voice services. Their total charged amount is 18 PKR across 9 transactions. They have made 14 purchases, with a total purchase value of 5156 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230220901940",
#         "User Insights": "User 9230220901940 has consumed 16 MB of data, sent 124 SMS, and used 334 minutes of voice calls. They have spent 0 PKR on data, 48 PKR on SMS, and 29 PKR on voice services. Their total charged amount is 77 PKR across 10 transactions. They have made 9 purchases, with a total purchase value of 4239 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230221414651",
#         "User Insights": "User 9230221414651 has consumed 234 MB of data, sent 159 SMS, and used 932 minutes of voice calls. They have spent 13 PKR on data, 45 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 62 PKR across 14 transactions. They have made 5 purchases, with a total purchase value of 2939 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230222425251",
#         "User Insights": "User 9230222425251 has consumed 125 MB of data, sent 124 SMS, and used 427 minutes of voice calls. They have spent 3 PKR on data, 26 PKR on SMS, and 29 PKR on voice services. Their total charged amount is 58 PKR across 11 transactions. They have made 11 purchases, with a total purchase value of 5843 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230223870632",
#         "User Insights": "User 9230223870632 has consumed 179 MB of data, sent 125 SMS, and used 508 minutes of voice calls. They have spent 18 PKR on data, 21 PKR on SMS, and 15 PKR on voice services. Their total charged amount is 54 PKR across 12 transactions. They have made 12 purchases, with a total purchase value of 5675 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230224461766",
#         "User Insights": "User 9230224461766 has consumed 89 MB of data, sent 74 SMS, and used 452 minutes of voice calls. They have spent 0 PKR on data, 8 PKR on SMS, and 3 PKR on voice services. Their total charged amount is 11 PKR across 8 transactions. They have made 7 purchases, with a total purchase value of 5013 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230224556190",
#         "User Insights": "User 9230224556190 has consumed 117 MB of data, sent 58 SMS, and used 392 minutes of voice calls. They have spent 5 PKR on data, 13 PKR on SMS, and 38 PKR on voice services. Their total charged amount is 56 PKR across 8 transactions. They have made 12 purchases, with a total purchase value of 6995 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230226068492",
#         "User Insights": "User 9230226068492 has consumed 194 MB of data, sent 74 SMS, and used 509 minutes of voice calls. They have spent 21 PKR on data, 15 PKR on SMS, and 31 PKR on voice services. Their total charged amount is 67 PKR across 10 transactions. They have made 12 purchases, with a total purchase value of 6734 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230230356648",
#         "User Insights": "User 9230230356648 has consumed 89 MB of data, sent 97 SMS, and used 524 minutes of voice calls. They have spent 8 PKR on data, 0 PKR on SMS, and 16 PKR on voice services. Their total charged amount is 24 PKR across 6 transactions. They have made 8 purchases, with a total purchase value of 3675 PKR. They have raised 16 support tickets."
#     },
#     {
#         "MSISDN": "9230231393360",
#         "User Insights": "User 9230231393360 has consumed 240 MB of data, sent 155 SMS, and used 360 minutes of voice calls. They have spent 15 PKR on data, 10 PKR on SMS, and 6 PKR on voice services. Their total charged amount is 31 PKR across 12 transactions. They have made 8 purchases, with a total purchase value of 3451 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230232190327",
#         "User Insights": "User 9230232190327 has consumed 134 MB of data, sent 110 SMS, and used 263 minutes of voice calls. They have spent 23 PKR on data, 11 PKR on SMS, and 31 PKR on voice services. Their total charged amount is 65 PKR across 10 transactions. They have made 9 purchases, with a total purchase value of 4733 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230233566905",
#         "User Insights": "User 9230233566905 has consumed 86 MB of data, sent 9 SMS, and used 290 minutes of voice calls. They have spent 35 PKR on data, 0 PKR on SMS, and 2 PKR on voice services. Their total charged amount is 37 PKR across 5 transactions. They have made 12 purchases, with a total purchase value of 7313 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230237322715",
#         "User Insights": "User 9230237322715 has consumed 129 MB of data, sent 65 SMS, and used 748 minutes of voice calls. They have spent 0 PKR on data, 2 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 16 PKR across 12 transactions. They have made 11 purchases, with a total purchase value of 4930 PKR. They have raised 5 support tickets."
#     },
#     {
#         "MSISDN": "9230237324066",
#         "User Insights": "User 9230237324066 has consumed 109 MB of data, sent 126 SMS, and used 671 minutes of voice calls. They have spent 25 PKR on data, 47 PKR on SMS, and 27 PKR on voice services. Their total charged amount is 99 PKR across 13 transactions. They have made 6 purchases, with a total purchase value of 3344 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230237841298",
#         "User Insights": "User 9230237841298 has consumed 93 MB of data, sent 8 SMS, and used 781 minutes of voice calls. They have spent 14 PKR on data, 5 PKR on SMS, and 39 PKR on voice services. Their total charged amount is 58 PKR across 7 transactions. They have made 1 purchases, with a total purchase value of 916 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230239925602",
#         "User Insights": "User 9230239925602 has consumed 107 MB of data, sent 48 SMS, and used 606 minutes of voice calls. They have spent 19 PKR on data, 13 PKR on SMS, and 5 PKR on voice services. Their total charged amount is 37 PKR across 9 transactions. They have made 9 purchases, with a total purchase value of 4054 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230240764422",
#         "User Insights": "User 9230240764422 has consumed 48 MB of data, sent 81 SMS, and used 341 minutes of voice calls. They have spent 1 PKR on data, 14 PKR on SMS, and 28 PKR on voice services. Their total charged amount is 43 PKR across 7 transactions. They have made 15 purchases, with a total purchase value of 5914 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230242009124",
#         "User Insights": "User 9230242009124 has consumed 327 MB of data, sent 0 SMS, and used 531 minutes of voice calls. They have spent 46 PKR on data, 0 PKR on SMS, and 39 PKR on voice services. Their total charged amount is 85 PKR across 13 transactions. They have made 9 purchases, with a total purchase value of 4905 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230243179920",
#         "User Insights": "User 9230243179920 has consumed 353 MB of data, sent 19 SMS, and used 32 minutes of voice calls. They have spent 71 PKR on data, 0 PKR on SMS, and 1 PKR on voice services. Their total charged amount is 72 PKR across 9 transactions. They have made 11 purchases, with a total purchase value of 7152 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230243910318",
#         "User Insights": "User 9230243910318 has consumed 64 MB of data, sent 199 SMS, and used 108 minutes of voice calls. They have spent 2 PKR on data, 65 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 67 PKR across 11 transactions. They have made 6 purchases, with a total purchase value of 3324 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230248021475",
#         "User Insights": "User 9230248021475 has consumed 0 MB of data, sent 74 SMS, and used 330 minutes of voice calls. They have spent 0 PKR on data, 12 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 23 PKR across 6 transactions. They have made 13 purchases, with a total purchase value of 6411 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230250373229",
#         "User Insights": "User 9230250373229 has consumed 0 MB of data, sent 42 SMS, and used 340 minutes of voice calls. They have spent 0 PKR on data, 6 PKR on SMS, and 34 PKR on voice services. Their total charged amount is 40 PKR across 5 transactions. They have made 11 purchases, with a total purchase value of 6492 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230252568240",
#         "User Insights": "User 9230252568240 has consumed 466 MB of data, sent 54 SMS, and used 738 minutes of voice calls. They have spent 50 PKR on data, 0 PKR on SMS, and 25 PKR on voice services. Their total charged amount is 75 PKR across 18 transactions. They have made 9 purchases, with a total purchase value of 5461 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230257976986",
#         "User Insights": "User 9230257976986 has consumed 58 MB of data, sent 148 SMS, and used 487 minutes of voice calls. They have spent 23 PKR on data, 0 PKR on SMS, and 15 PKR on voice services. Their total charged amount is 38 PKR across 9 transactions. They have made 13 purchases, with a total purchase value of 6994 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230259441946",
#         "User Insights": "User 9230259441946 has consumed 110 MB of data, sent 119 SMS, and used 121 minutes of voice calls. They have spent 12 PKR on data, 23 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 35 PKR across 7 transactions. They have made 10 purchases, with a total purchase value of 7211 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230260106137",
#         "User Insights": "User 9230260106137 has consumed 131 MB of data, sent 86 SMS, and used 1113 minutes of voice calls. They have spent 14 PKR on data, 14 PKR on SMS, and 25 PKR on voice services. Their total charged amount is 53 PKR across 15 transactions. They have made 15 purchases, with a total purchase value of 8320 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230261321312",
#         "User Insights": "User 9230261321312 has consumed 92 MB of data, sent 94 SMS, and used 836 minutes of voice calls. They have spent 12 PKR on data, 12 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 44 PKR across 10 transactions. They have made 2 purchases, with a total purchase value of 161 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230262593890",
#         "User Insights": "User 9230262593890 has consumed 142 MB of data, sent 2 SMS, and used 127 minutes of voice calls. They have spent 23 PKR on data, 0 PKR on SMS, and 7 PKR on voice services. Their total charged amount is 30 PKR across 5 transactions. They have made 14 purchases, with a total purchase value of 6536 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230265833817",
#         "User Insights": "User 9230265833817 has consumed 243 MB of data, sent 91 SMS, and used 412 minutes of voice calls. They have spent 31 PKR on data, 23 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 54 PKR across 14 transactions. They have made 12 purchases, with a total purchase value of 7104 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230267833934",
#         "User Insights": "User 9230267833934 has consumed 0 MB of data, sent 0 SMS, and used 398 minutes of voice calls. They have spent 0 PKR on data, 0 PKR on SMS, and 10 PKR on voice services. Their total charged amount is 10 PKR across 3 transactions. They have made 12 purchases, with a total purchase value of 6589 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230269592945",
#         "User Insights": "User 9230269592945 has consumed 0 MB of data, sent 114 SMS, and used 363 minutes of voice calls. They have spent 0 PKR on data, 21 PKR on SMS, and 30 PKR on voice services. Their total charged amount is 51 PKR across 7 transactions. They have made 12 purchases, with a total purchase value of 6441 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230270449680",
#         "User Insights": "User 9230270449680 has consumed 214 MB of data, sent 120 SMS, and used 492 minutes of voice calls. They have spent 8 PKR on data, 2 PKR on SMS, and 32 PKR on voice services. Their total charged amount is 42 PKR across 11 transactions. They have made 15 purchases, with a total purchase value of 8392 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230270654265",
#         "User Insights": "User 9230270654265 has consumed 26 MB of data, sent 156 SMS, and used 259 minutes of voice calls. They have spent 8 PKR on data, 63 PKR on SMS, and 8 PKR on voice services. Their total charged amount is 79 PKR across 7 transactions. They have made 11 purchases, with a total purchase value of 5509 PKR. They have raised 4 support tickets."
#     },
#     {
#         "MSISDN": "9230273259061",
#         "User Insights": "User 9230273259061 has consumed 221 MB of data, sent 141 SMS, and used 402 minutes of voice calls. They have spent 0 PKR on data, 49 PKR on SMS, and 17 PKR on voice services. Their total charged amount is 66 PKR across 10 transactions. They have made 6 purchases, with a total purchase value of 2440 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230274619633",
#         "User Insights": "User 9230274619633 has consumed 166 MB of data, sent 141 SMS, and used 889 minutes of voice calls. They have spent 11 PKR on data, 13 PKR on SMS, and 39 PKR on voice services. Their total charged amount is 63 PKR across 11 transactions. They have made 14 purchases, with a total purchase value of 5579 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230276004324",
#         "User Insights": "User 9230276004324 has consumed 295 MB of data, sent 92 SMS, and used 161 minutes of voice calls. They have spent 16 PKR on data, 18 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 34 PKR across 11 transactions. They have made 11 purchases, with a total purchase value of 7257 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230276660407",
#         "User Insights": "User 9230276660407 has consumed 12 MB of data, sent 51 SMS, and used 408 minutes of voice calls. They have spent 0 PKR on data, 16 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 40 PKR across 5 transactions. They have made 18 purchases, with a total purchase value of 10954 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230277017963",
#         "User Insights": "User 9230277017963 has consumed 209 MB of data, sent 3 SMS, and used 613 minutes of voice calls. They have spent 38 PKR on data, 5 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 67 PKR across 11 transactions. They have made 12 purchases, with a total purchase value of 5479 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230277146142",
#         "User Insights": "User 9230277146142 has consumed 156 MB of data, sent 111 SMS, and used 502 minutes of voice calls. They have spent 11 PKR on data, 35 PKR on SMS, and 30 PKR on voice services. Their total charged amount is 76 PKR across 10 transactions. They have made 7 purchases, with a total purchase value of 3741 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230277713469",
#         "User Insights": "User 9230277713469 has consumed 175 MB of data, sent 119 SMS, and used 771 minutes of voice calls. They have spent 21 PKR on data, 53 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 98 PKR across 10 transactions. They have made 17 purchases, with a total purchase value of 8177 PKR. They have raised 3 support tickets."
#     },
#     {
#         "MSISDN": "9230279476066",
#         "User Insights": "User 9230279476066 has consumed 0 MB of data, sent 121 SMS, and used 108 minutes of voice calls. They have spent 0 PKR on data, 18 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 18 PKR across 5 transactions. They have made 13 purchases, with a total purchase value of 6208 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230280094327",
#         "User Insights": "User 9230280094327 has consumed 82 MB of data, sent 19 SMS, and used 123 minutes of voice calls. They have spent 0 PKR on data, 0 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 20 PKR across 5 transactions. They have made 13 purchases, with a total purchase value of 7526 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230281653523",
#         "User Insights": "User 9230281653523 has consumed 134 MB of data, sent 49 SMS, and used 1011 minutes of voice calls. They have spent 19 PKR on data, 0 PKR on SMS, and 23 PKR on voice services. Their total charged amount is 42 PKR across 10 transactions. They have made 12 purchases, with a total purchase value of 7585 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230283219045",
#         "User Insights": "User 9230283219045 has consumed 3 MB of data, sent 65 SMS, and used 8 minutes of voice calls. They have spent 3 PKR on data, 9 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 26 PKR across 4 transactions. They have made 8 purchases, with a total purchase value of 3847 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230283949996",
#         "User Insights": "User 9230283949996 has consumed 289 MB of data, sent 50 SMS, and used 650 minutes of voice calls. They have spent 6 PKR on data, 0 PKR on SMS, and 32 PKR on voice services. Their total charged amount is 38 PKR across 11 transactions. They have made 9 purchases, with a total purchase value of 3998 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230284527343",
#         "User Insights": "User 9230284527343 has consumed 61 MB of data, sent 134 SMS, and used 607 minutes of voice calls. They have spent 2 PKR on data, 4 PKR on SMS, and 31 PKR on voice services. Their total charged amount is 37 PKR across 10 transactions. They have made 10 purchases, with a total purchase value of 5751 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230284966704",
#         "User Insights": "User 9230284966704 has consumed 190 MB of data, sent 71 SMS, and used 1348 minutes of voice calls. They have spent 47 PKR on data, 22 PKR on SMS, and 69 PKR on voice services. Their total charged amount is 138 PKR across 17 transactions. They have made 7 purchases, with a total purchase value of 4013 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230286090141",
#         "User Insights": "User 9230286090141 has consumed 57 MB of data, sent 0 SMS, and used 391 minutes of voice calls. They have spent 0 PKR on data, 0 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 0 PKR across 5 transactions. They have made 12 purchases, with a total purchase value of 6379 PKR. They have raised 16 support tickets."
#     },
#     {
#         "MSISDN": "9230286659796",
#         "User Insights": "User 9230286659796 has consumed 312 MB of data, sent 46 SMS, and used 937 minutes of voice calls. They have spent 34 PKR on data, 7 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 45 PKR across 14 transactions. They have made 13 purchases, with a total purchase value of 7458 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230289915767",
#         "User Insights": "User 9230289915767 has consumed 79 MB of data, sent 119 SMS, and used 221 minutes of voice calls. They have spent 24 PKR on data, 0 PKR on SMS, and 20 PKR on voice services. Their total charged amount is 44 PKR across 8 transactions. They have made 7 purchases, with a total purchase value of 3245 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230291832784",
#         "User Insights": "User 9230291832784 has consumed 367 MB of data, sent 161 SMS, and used 1544 minutes of voice calls. They have spent 20 PKR on data, 41 PKR on SMS, and 37 PKR on voice services. Their total charged amount is 98 PKR across 21 transactions. They have made 4 purchases, with a total purchase value of 3106 PKR. They have raised 5 support tickets."
#     },
#     {
#         "MSISDN": "9230292005339",
#         "User Insights": "User 9230292005339 has consumed 130 MB of data, sent 18 SMS, and used 382 minutes of voice calls. They have spent 12 PKR on data, 4 PKR on SMS, and 6 PKR on voice services. Their total charged amount is 22 PKR across 8 transactions. They have made 11 purchases, with a total purchase value of 6747 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230292331082",
#         "User Insights": "User 9230292331082 has consumed 98 MB of data, sent 62 SMS, and used 351 minutes of voice calls. They have spent 0 PKR on data, 46 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 70 PKR across 8 transactions. They have made 12 purchases, with a total purchase value of 6762 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230293207299",
#         "User Insights": "User 9230293207299 has consumed 172 MB of data, sent 155 SMS, and used 449 minutes of voice calls. They have spent 68 PKR on data, 33 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 115 PKR across 16 transactions. They have made 7 purchases, with a total purchase value of 4211 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230293952148",
# ...
#     },
#     {
#         "MSISDN": "9230926844978",
#         "User Insights": "User 9230926844978 has consumed 19 MB of data, sent 60 SMS, and used 343 minutes of voice calls. They have spent 10 PKR on data, 15 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 36 PKR across 6 transactions. They have made 8 purchases, with a total purchase value of 4837 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230927056639",
#         "User Insights": "User 9230927056639 has consumed 140 MB of data, sent 7 SMS, and used 746 minutes of voice calls. They have spent 11 PKR on data, 0 PKR on SMS, and 16 PKR on voice services. Their total charged amount is 27 PKR across 7 transactions. They have made 17 purchases, with a total purchase value of 9627 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230927069977",
#         "User Insights": "User 9230927069977 has consumed 220 MB of data, sent 148 SMS, and used 653 minutes of voice calls. They have spent 41 PKR on data, 38 PKR on SMS, and 37 PKR on voice services. Their total charged amount is 116 PKR across 16 transactions. They have made 7 purchases, with a total purchase value of 3901 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230927917724",
#         "User Insights": "User 9230927917724 has consumed 311 MB of data, sent 72 SMS, and used 296 minutes of voice calls. They have spent 52 PKR on data, 5 PKR on SMS, and 16 PKR on voice services. Their total charged amount is 73 PKR across 11 transactions. They have made 12 purchases, with a total purchase value of 6729 PKR. They have raised 11 support tickets."
#     },
#     {
#         "MSISDN": "9230929167854",
#         "User Insights": "User 9230929167854 has consumed 241 MB of data, sent 73 SMS, and used 408 minutes of voice calls. They have spent 25 PKR on data, 48 PKR on SMS, and 11 PKR on voice services. Their total charged amount is 84 PKR across 10 transactions. They have made 11 purchases, with a total purchase value of 5182 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230933143804",
#         "User Insights": "User 9230933143804 has consumed 182 MB of data, sent 110 SMS, and used 258 minutes of voice calls. They have spent 40 PKR on data, 15 PKR on SMS, and 26 PKR on voice services. Their total charged amount is 81 PKR across 9 transactions. They have made 12 purchases, with a total purchase value of 6777 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230934702779",
#         "User Insights": "User 9230934702779 has consumed 218 MB of data, sent 101 SMS, and used 234 minutes of voice calls. They have spent 32 PKR on data, 34 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 80 PKR across 11 transactions. They have made 3 purchases, with a total purchase value of 1786 PKR. They have raised 6 support tickets."
#     },
#     {
#         "MSISDN": "9230934867447",
#         "User Insights": "User 9230934867447 has consumed 125 MB of data, sent 17 SMS, and used 821 minutes of voice calls. They have spent 4 PKR on data, 0 PKR on SMS, and 35 PKR on voice services. Their total charged amount is 39 PKR across 10 transactions. They have made 10 purchases, with a total purchase value of 4749 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230935333762",
#         "User Insights": "User 9230935333762 has consumed 84 MB of data, sent 204 SMS, and used 584 minutes of voice calls. They have spent 15 PKR on data, 23 PKR on SMS, and 12 PKR on voice services. Their total charged amount is 50 PKR across 14 transactions. They have made 8 purchases, with a total purchase value of 5233 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230938865042",
#         "User Insights": "User 9230938865042 has consumed 198 MB of data, sent 72 SMS, and used 594 minutes of voice calls. They have spent 20 PKR on data, 29 PKR on SMS, and 39 PKR on voice services. Their total charged amount is 88 PKR across 10 transactions. They have made 8 purchases, with a total purchase value of 3520 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230940913341",
#         "User Insights": "User 9230940913341 has consumed 139 MB of data, sent 63 SMS, and used 863 minutes of voice calls. They have spent 12 PKR on data, 0 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 36 PKR across 9 transactions. They have made 8 purchases, with a total purchase value of 5664 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230942028822",
#         "User Insights": "User 9230942028822 has consumed 7 MB of data, sent 79 SMS, and used 463 minutes of voice calls. They have spent 18 PKR on data, 15 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 47 PKR across 8 transactions. They have made 11 purchases, with a total purchase value of 5125 PKR. They have raised 4 support tickets."
#     },
#     {
#         "MSISDN": "9230945377575",
#         "User Insights": "User 9230945377575 has consumed 74 MB of data, sent 46 SMS, and used 245 minutes of voice calls. They have spent 12 PKR on data, 2 PKR on SMS, and 3 PKR on voice services. Their total charged amount is 17 PKR across 5 transactions. They have made 8 purchases, with a total purchase value of 4464 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230949419871",
#         "User Insights": "User 9230949419871 has consumed 58 MB of data, sent 47 SMS, and used 478 minutes of voice calls. They have spent 0 PKR on data, 23 PKR on SMS, and 27 PKR on voice services. Their total charged amount is 50 PKR across 8 transactions. They have made 10 purchases, with a total purchase value of 6167 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230949423190",
#         "User Insights": "User 9230949423190 has consumed 227 MB of data, sent 93 SMS, and used 118 minutes of voice calls. They have spent 18 PKR on data, 13 PKR on SMS, and 8 PKR on voice services. Their total charged amount is 39 PKR across 9 transactions. They have made 11 purchases, with a total purchase value of 5187 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230951046596",
#         "User Insights": "User 9230951046596 has consumed 292 MB of data, sent 156 SMS, and used 359 minutes of voice calls. They have spent 29 PKR on data, 16 PKR on SMS, and 29 PKR on voice services. Their total charged amount is 74 PKR across 12 transactions. They have made 10 purchases, with a total purchase value of 5378 PKR. They have raised 14 support tickets."
#     },
#     {
#         "MSISDN": "9230951173620",
#         "User Insights": "User 9230951173620 has consumed 168 MB of data, sent 116 SMS, and used 1109 minutes of voice calls. They have spent 11 PKR on data, 37 PKR on SMS, and 53 PKR on voice services. Their total charged amount is 101 PKR across 16 transactions. They have made 10 purchases, with a total purchase value of 3226 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230952507106",
#         "User Insights": "User 9230952507106 has consumed 192 MB of data, sent 205 SMS, and used 651 minutes of voice calls. They have spent 34 PKR on data, 37 PKR on SMS, and 42 PKR on voice services. Their total charged amount is 113 PKR across 13 transactions. They have made 17 purchases, with a total purchase value of 9306 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230957219651",
#         "User Insights": "User 9230957219651 has consumed 123 MB of data, sent 173 SMS, and used 435 minutes of voice calls. They have spent 14 PKR on data, 27 PKR on SMS, and 24 PKR on voice services. Their total charged amount is 65 PKR across 11 transactions. They have made 15 purchases, with a total purchase value of 5415 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230958106815",
#         "User Insights": "User 9230958106815 has consumed 205 MB of data, sent 56 SMS, and used 484 minutes of voice calls. They have spent 18 PKR on data, 11 PKR on SMS, and 5 PKR on voice services. Their total charged amount is 34 PKR across 8 transactions. They have made 12 purchases, with a total purchase value of 4528 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230963789911",
#         "User Insights": "User 9230963789911 has consumed 136 MB of data, sent 156 SMS, and used 697 minutes of voice calls. They have spent 29 PKR on data, 12 PKR on SMS, and 1 PKR on voice services. Their total charged amount is 42 PKR across 10 transactions. They have made 12 purchases, with a total purchase value of 7380 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230965222030",
#         "User Insights": "User 9230965222030 has consumed 183 MB of data, sent 62 SMS, and used 392 minutes of voice calls. They have spent 23 PKR on data, 0 PKR on SMS, and 26 PKR on voice services. Their total charged amount is 49 PKR across 9 transactions. They have made 11 purchases, with a total purchase value of 3480 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230966239325",
#         "User Insights": "User 9230966239325 has consumed 224 MB of data, sent 35 SMS, and used 259 minutes of voice calls. They have spent 20 PKR on data, 3 PKR on SMS, and 14 PKR on voice services. Their total charged amount is 37 PKR across 10 transactions. They have made 11 purchases, with a total purchase value of 5767 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230974624965",
#         "User Insights": "User 9230974624965 has consumed 329 MB of data, sent 134 SMS, and used 1266 minutes of voice calls. They have spent 35 PKR on data, 32 PKR on SMS, and 22 PKR on voice services. Their total charged amount is 89 PKR across 16 transactions. They have made 12 purchases, with a total purchase value of 7220 PKR. They have raised 16 support tickets."
#     },
#     {
#         "MSISDN": "9230975398588",
#         "User Insights": "User 9230975398588 has consumed 302 MB of data, sent 145 SMS, and used 926 minutes of voice calls. They have spent 42 PKR on data, 33 PKR on SMS, and 32 PKR on voice services. Their total charged amount is 107 PKR across 18 transactions. They have made 7 purchases, with a total purchase value of 4175 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230980574168",
#         "User Insights": "User 9230980574168 has consumed 133 MB of data, sent 103 SMS, and used 185 minutes of voice calls. They have spent 48 PKR on data, 49 PKR on SMS, and 12 PKR on voice services. Their total charged amount is 109 PKR across 9 transactions. They have made 6 purchases, with a total purchase value of 3756 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230986337820",
#         "User Insights": "User 9230986337820 has consumed 68 MB of data, sent 90 SMS, and used 697 minutes of voice calls. They have spent 0 PKR on data, 16 PKR on SMS, and 45 PKR on voice services. Their total charged amount is 61 PKR across 10 transactions. They have made 8 purchases, with a total purchase value of 4072 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230988629670",
#         "User Insights": "User 9230988629670 has consumed 364 MB of data, sent 94 SMS, and used 1327 minutes of voice calls. They have spent 49 PKR on data, 16 PKR on SMS, and 13 PKR on voice services. Their total charged amount is 78 PKR across 17 transactions. They have made 12 purchases, with a total purchase value of 7187 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230989253929",
#         "User Insights": "User 9230989253929 has consumed 465 MB of data, sent 38 SMS, and used 165 minutes of voice calls. They have spent 58 PKR on data, 36 PKR on SMS, and 0 PKR on voice services. Their total charged amount is 94 PKR across 13 transactions. They have made 10 purchases, with a total purchase value of 5264 PKR. They have raised 8 support tickets."
#     },
#     {
#         "MSISDN": "9230991595287",
#         "User Insights": "User 9230991595287 has consumed 126 MB of data, sent 208 SMS, and used 636 minutes of voice calls. They have spent 10 PKR on data, 22 PKR on SMS, and 23 PKR on voice services. Their total charged amount is 55 PKR across 14 transactions. They have made 7 purchases, with a total purchase value of 3514 PKR. They have raised 12 support tickets."
#     },
#     {
#         "MSISDN": "9230993322733",
#         "User Insights": "User 9230993322733 has consumed 266 MB of data, sent 31 SMS, and used 212 minutes of voice calls. They have spent 23 PKR on data, 0 PKR on SMS, and 36 PKR on voice services. Their total charged amount is 59 PKR across 9 transactions. They have made 8 purchases, with a total purchase value of 3878 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230993414106",
#         "User Insights": "User 9230993414106 has consumed 166 MB of data, sent 84 SMS, and used 364 minutes of voice calls. They have spent 5 PKR on data, 0 PKR on SMS, and 4 PKR on voice services. Their total charged amount is 9 PKR across 9 transactions. They have made 7 purchases, with a total purchase value of 4136 PKR. They have raised 10 support tickets."
#     },
#     {
#         "MSISDN": "9230995147362",
#         "User Insights": "User 9230995147362 has consumed 48 MB of data, sent 57 SMS, and used 936 minutes of voice calls. They have spent 0 PKR on data, 43 PKR on SMS, and 7 PKR on voice services. Their total charged amount is 50 PKR across 8 transactions. They have made 10 purchases, with a total purchase value of 6163 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230996123791",
#         "User Insights": "User 9230996123791 has consumed 65 MB of data, sent 0 SMS, and used 464 minutes of voice calls. They have spent 0 PKR on data, 0 PKR on SMS, and 30 PKR on voice services. Their total charged amount is 30 PKR across 4 transactions. They have made 10 purchases, with a total purchase value of 5721 PKR. They have raised 9 support tickets."
#     },
#     {
#         "MSISDN": "9230996583212",
#         "User Insights": "User 9230996583212 has consumed 35 MB of data, sent 65 SMS, and used 476 minutes of voice calls. They have spent 8 PKR on data, 10 PKR on SMS, and 3 PKR on voice services. Their total charged amount is 21 PKR across 7 transactions. They have made 9 purchases, with a total purchase value of 3651 PKR. They have raised 15 support tickets."
#     },
#     {
#         "MSISDN": "9230996629579",
#         "User Insights": "User 9230996629579 has consumed 182 MB of data, sent 60 SMS, and used 333 minutes of voice calls. They have spent 22 PKR on data, 0 PKR on SMS, and 5 PKR on voice services. Their total charged amount is 27 PKR across 8 transactions. They have made 17 purchases, with a total purchase value of 9068 PKR. They have raised 7 support tickets."
#     },
#     {
#         "MSISDN": "9230998618451",
#         "User Insights": "User 9230998618451 has consumed 370 MB of data, sent 68 SMS, and used 298 minutes of voice calls. They have spent 46 PKR on data, 41 PKR on SMS, and 13 PKR on voice services. Their total charged amount is 100 PKR across 15 transactions. They have made 8 purchases, with a total purchase value of 5723 PKR. They have raised 13 support tickets."
#     },
#     {
#         "MSISDN": "9230999762562",
#         "User Insights": "User 9230999762562 has consumed 278 MB of data, sent 93 SMS, and used 216 minutes of voice calls. They have spent 29 PKR on data, 7 PKR on SMS, and 28 PKR on voice services. Their total charged amount is 64 PKR across 10 transactions. They have made 13 purchases, with a total purchase value of 5609 PKR. They have raised 15 support tickets."
#     }
# ]

# %%
# Saving Formatted Consumer Insights Summary

consumer_insights_formatted_path = "processed/consumer_insights_formatted.json"

with open(consumer_insights_formatted_path, "w", encoding="utf-8") as f:
    json.dump(formatted_insights, f, indent=4)

print(f"Saved formatted consumer insights summary.")
# Out:
# Saved formatted consumer insights summary.

# %%
# Processing Consumer_Insights_Summary for Embeddings

general_insights_path = "processed/general_insights_summary.json"

with open(general_insights_path, "r", encoding="utf-8") as file:
    general_insights = json.load(file)["General Insights"]

def format_regional_popularity(region_data):
    return [
        f"The city of {entry['City']} has {entry['User_Count']} active users."
        for entry in region_data
    ]

def format_user_type_distribution(user_type_data):
    return [
        f"There are {entry['Count']} {entry['User_Type']} users in the network."
        for entry in user_type_data
    ]

def format_regional_user_type_distribution(region_data, city_data):
    return [
        f"In {city_data[i]['City']}, there are {entry['Postpaid']} postpaid users and {entry['Prepaid']} prepaid users."
        for i, entry in enumerate(region_data)
    ]

def format_most_common_tickets(ticket_data):
    return [
        f"The '{entry['Category']}' category has {entry['Ticket_Count']} support tickets."
        for entry in ticket_data
    ]

def format_resolution_time(resolution_data):
    return [
        f"The average resolution time for '{entry['Category']}' tickets is {round(entry['Avg_Resolution_Hours'], 2)} hours."
        for entry in resolution_data
    ]

formatted_general_insights = {
    "Regional Popularity": format_regional_popularity(general_insights["Regional Popularity"]),
    "User Type Distribution": format_user_type_distribution(general_insights["User Type Distribution"]),
    "Regional User Type Distribution": format_regional_user_type_distribution(
        general_insights["Regional User Type Distribution"],
        general_insights["Regional Popularity"]
    ),
    "Most Common Ticket Categories": format_most_common_tickets(general_insights["Most Common Ticket Categories"]),
    "Average Resolution Time Per Ticket Category": format_resolution_time(general_insights["Average Resolution Time Per Ticket Category"])
}

print(json.dumps(formatted_general_insights, indent=4))
# Out:
# {
#     "Regional Popularity": [
#         "The city of Quetta has 75 active users.",
#         "The city of Lahore has 73 active users.",
#         "The city of Peshawar has 62 active users.",
#         "The city of Faisalabad has 61 active users.",
#         "The city of Rawalpindi has 60 active users.",
#         "The city of Islamabad has 59 active users.",
#         "The city of Multan has 58 active users.",
#         "The city of Karachi has 52 active users."
#     ],
#     "User Type Distribution": [
#         "There are 263 Postpaid users in the network.",
#         "There are 237 Prepaid users in the network."
#     ],
#     "Regional User Type Distribution": [
#         "In Quetta, there are 33 postpaid users and 28 prepaid users.",
#         "In Lahore, there are 32 postpaid users and 27 prepaid users.",
#         "In Peshawar, there are 24 postpaid users and 28 prepaid users.",
#         "In Faisalabad, there are 42 postpaid users and 31 prepaid users.",
#         "In Rawalpindi, there are 27 postpaid users and 31 prepaid users.",
#         "In Islamabad, there are 40 postpaid users and 22 prepaid users.",
#         "In Multan, there are 35 postpaid users and 40 prepaid users.",
#         "In Karachi, there are 30 postpaid users and 30 prepaid users."
#     ],
#     "Most Common Ticket Categories": [
#         "The 'Network Issue' category has 1018 support tickets.",
#         "The 'General Inquiry' category has 1015 support tickets.",
#         "The 'Technical Support' category has 1013 support tickets.",
#         "The 'Billing' category has 1009 support tickets.",
#         "The 'Complaint' category has 945 support tickets."
#     ],
#     "Average Resolution Time Per Ticket Category": [
#         "The average resolution time for 'Billing' tickets is 36.51 hours.",
#         "The average resolution time for 'Complaint' tickets is 37.36 hours.",
#         "The average resolution time for 'General Inquiry' tickets is 37.31 hours.",
#         "The average resolution time for 'Network Issue' tickets is 36.8 hours.",
#         "The average resolution time for 'Technical Support' tickets is 36.83 hours."
#     ]
# }

# %%
# Saving Formatted General Insights Summary

general_insights_formatted_path = "processed/general_insights_formatted.json"

with open(general_insights_formatted_path, "w", encoding="utf-8") as f:
    json.dump(formatted_general_insights, f, indent=4)

print(f"Saved formatted general insights summary.")
# Out:
# Saved formatted general insights summary.
